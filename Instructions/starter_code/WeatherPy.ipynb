# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
units = "imperial"
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# %%
 # Creating empty lists for the dataframe
city_data = []
clouds = []
dates = []
humidity = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
record_count = 0
set_count = 1

# %%
# print['Beginning Data Retrieval']
# print['-----------------------------']

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(url + city.replace(" ","&")).json()
        clouds.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if record_count > 50:
            record_count = 1
            set_count += 1
            city_data.append(city)
        else:
            record_count += 1
            city_data.append(city)
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | vostok
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | bandrele
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# City not found. Skipping...
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | wewak
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | haines junction
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | akyab
# Processing Record 20 of Set 1 | saint-augustin
# Processing Record 21 of Set 1 | corrente
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | esperance
# Processing Record 25 of Set 1 | chapais
# Processing Record 26 of Set 1 | tautira
# City not found. Skipping...
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | deputatskiy
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | buta
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | paamiut
# Processing Record 44 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | avera
# Processing Record 47 of Set 1 | kuytun
# Processing Record 48 of Set 1 | orasac
# Processing Record 49 of Set 1 | boca do acre
# Processing Record 50 of Set 1 | provideniya
# Processing Record 51 of Set 1 | richards bay
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | nador
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | sabang
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | somanda
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | abatskoye
# Processing Record 10 of Set 2 | bamora
# Processing Record 11 of Set 2 | ubinskoye
# Processing Record 12 of Set 2 | inirida
# Processing Record 13 of Set 2 | husavik
# Processing Record 14 of Set 2 | mount gambier
# City not found. Skipping...
# Processing Record 15 of Set 2 | sainte-anne-des-monts
# Processing Record 16 of Set 2 | popova
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | udarnyy
# Processing Record 19 of Set 2 | gotsu
# City not found. Skipping...
# Processing Record 20 of Set 2 | along
# Processing Record 21 of Set 2 | brae
# Processing Record 22 of Set 2 | tilichiki
# Processing Record 23 of Set 2 | westport
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | ferrol
# City not found. Skipping...
# Processing Record 27 of Set 2 | coihueco
# Processing Record 28 of Set 2 | lakes entrance
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | san carlos de bariloche
# Processing Record 32 of Set 2 | suhbaatar
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | geraldton
# City not found. Skipping...
# Processing Record 35 of Set 2 | ola
# Processing Record 36 of Set 2 | moose factory
# Processing Record 37 of Set 2 | asfi
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | galich
# Processing Record 41 of Set 2 | mahebourg
# Processing Record 42 of Set 2 | torbeyevo
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | tandalti
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | chipinge
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | pravia
# Processing Record 49 of Set 2 | leningradskiy
# Processing Record 50 of Set 2 | zhangye
# Processing Record 51 of Set 2 | hede
# City not found. Skipping...
# Processing Record 1 of Set 3 | hindaun
# Processing Record 2 of Set 3 | neya
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | quelimane
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | calama
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | kushiro
# Processing Record 13 of Set 3 | sembakung
# Processing Record 14 of Set 3 | bowen
# Processing Record 15 of Set 3 | bambous virieux
# City not found. Skipping...
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | tazmalt
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | fukue
# Processing Record 21 of Set 3 | kunming
# Processing Record 22 of Set 3 | manitouwadge
# Processing Record 23 of Set 3 | shache
# Processing Record 24 of Set 3 | sao miguel do araguaia
# Processing Record 25 of Set 3 | cam ranh
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | dobroye
# Processing Record 28 of Set 3 | lac du bonnet
# Processing Record 29 of Set 3 | forio
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | sola
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | dalnerechensk
# Processing Record 36 of Set 3 | vieques
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | trairi
# Processing Record 39 of Set 3 | maniitsoq
# Processing Record 40 of Set 3 | zhigansk
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | biak
# Processing Record 43 of Set 3 | teguise
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | cidreira
# City not found. Skipping...
# Processing Record 46 of Set 3 | teguldet
# Processing Record 47 of Set 3 | campos gerais
# Processing Record 48 of Set 3 | saint-felix-de-valois
# Processing Record 49 of Set 3 | leh
# Processing Record 50 of Set 3 | newport
# Processing Record 51 of Set 3 | kiunga
# Processing Record 1 of Set 4 | vanavara
# Processing Record 2 of Set 4 | gravelbourg
# Processing Record 3 of Set 4 | lata
# Processing Record 4 of Set 4 | nuuk
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | dukat
# Processing Record 7 of Set 4 | berdigestyakh
# Processing Record 8 of Set 4 | sitka
# City not found. Skipping...
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | taloqan
# Processing Record 13 of Set 4 | hovd
# Processing Record 14 of Set 4 | bilma
# Processing Record 15 of Set 4 | zhangjiakou
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | shimoda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 4 | oktyabrskiy
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | buchanan
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | puerto ayacucho
# Processing Record 23 of Set 4 | yuli
# Processing Record 24 of Set 4 | shemonaikha
# Processing Record 25 of Set 4 | awjilah
# Processing Record 26 of Set 4 | batagay
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | noyabrsk
# Processing Record 29 of Set 4 | eyl
# Processing Record 30 of Set 4 | kodinsk
# Processing Record 31 of Set 4 | launceston
# Processing Record 32 of Set 4 | matsusaka
# City not found. Skipping...
# Processing Record 33 of Set 4 | liling
# Processing Record 34 of Set 4 | sovetskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 4 | pacific grove
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | naryan-mar
# Processing Record 39 of Set 4 | redmond
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | palu
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | lethem
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 4 | ghanzi
# Processing Record 45 of Set 4 | oranjemund
# Processing Record 46 of Set 4 | tres arroyos
# Processing Record 47 of Set 4 | lazaro cardenas
# City not found. Skipping...
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | inhambane
# Processing Record 50 of Set 4 | bonavista
# Processing Record 51 of Set 4 | cheyenne
# Processing Record 1 of Set 5 | xining
# Processing Record 2 of Set 5 | cabinda
# Processing Record 3 of Set 5 | santiago
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | barcelona
# City not found. Skipping...
# Processing Record 6 of Set 5 | sinjar
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | marsabit
# Processing Record 10 of Set 5 | grindavik
# Processing Record 11 of Set 5 | fairbanks
# Processing Record 12 of Set 5 | nemuro
# Processing Record 13 of Set 5 | banda aceh
# Processing Record 14 of Set 5 | auki
# Processing Record 15 of Set 5 | saint-pierre
# Processing Record 16 of Set 5 | karratha
# Processing Record 17 of Set 5 | shu
# Processing Record 18 of Set 5 | seaside
# Processing Record 19 of Set 5 | arrifes
# Processing Record 20 of Set 5 | pangnirtung
# Processing Record 21 of Set 5 | kinston
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | carlagan
# Processing Record 24 of Set 5 | red bluff
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | verkhoyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | altinopolis
# Processing Record 30 of Set 5 | coldingham
# Processing Record 31 of Set 5 | bintulu
# Processing Record 32 of Set 5 | ust-maya
# Processing Record 33 of Set 5 | izhma
# Processing Record 34 of Set 5 | severo-yeniseyskiy
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | antofagasta
# Processing Record 37 of Set 5 | warren
# Processing Record 38 of Set 5 | udachnyy
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | sobradinho
# Processing Record 41 of Set 5 | iwanai
# Processing Record 42 of Set 5 | avarua
# Processing Record 43 of Set 5 | zaysan
# Processing Record 44 of Set 5 | northallerton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 5 | havelock
# Processing Record 46 of Set 5 | pombas
# Processing Record 47 of Set 5 | barberton
# Processing Record 48 of Set 5 | klaksvik
# Processing Record 49 of Set 5 | tsabong
# Processing Record 50 of Set 5 | luderitz
# Processing Record 51 of Set 5 | faanui
# Processing Record 1 of Set 6 | nelson bay
# Processing Record 2 of Set 6 | bubaque
# City not found. Skipping...
# Processing Record 3 of Set 6 | puerto varas
# Processing Record 4 of Set 6 | colesberg
# Processing Record 5 of Set 6 | port hardy
# City not found. Skipping...
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | varzelandia
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | altay
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | dalvik
# City not found. Skipping...
# Processing Record 12 of Set 6 | hami
# Processing Record 13 of Set 6 | imeni poliny osipenko
# City not found. Skipping...
# Processing Record 14 of Set 6 | agadir
# Processing Record 15 of Set 6 | kuah
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | pandan niog
# City not found. Skipping...
# Processing Record 18 of Set 6 | ilo
# Processing Record 19 of Set 6 | norfolk
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | viedma
# Processing Record 22 of Set 6 | kommunar
# Processing Record 23 of Set 6 | ocampo
# Processing Record 24 of Set 6 | jos
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | pangai
# Processing Record 27 of Set 6 | colares
# Processing Record 28 of Set 6 | carbonia
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | zhicheng
# Processing Record 31 of Set 6 | waitati
# Processing Record 32 of Set 6 | japura
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | severodvinsk
# Processing Record 35 of Set 6 | kuzhorskaya
# City not found. Skipping...
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | lincoln
# Processing Record 38 of Set 6 | rasht
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | otradnoye
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | cartagena del chaira
# Processing Record 43 of Set 6 | labuhan
# City not found. Skipping...
# Processing Record 44 of Set 6 | kerema
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | yarada
# Processing Record 47 of Set 6 | bereda
# City not found. Skipping...
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | butaritari
# Processing Record 50 of Set 6 | kindersley
# Processing Record 51 of Set 6 | matongo
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | esmeraldas
# Processing Record 3 of Set 7 | cabedelo
# Processing Record 4 of Set 7 | verkhnevilyuysk
# Processing Record 5 of Set 7 | saint-francois
# Processing Record 6 of Set 7 | sydney
# Processing Record 7 of Set 7 | boa vista
# City not found. Skipping...
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | khasan
# Processing Record 10 of Set 7 | atasu
# Processing Record 11 of Set 7 | thinadhoo
# City not found. Skipping...
# Processing Record 12 of Set 7 | andenes
# Processing Record 13 of Set 7 | huarmey
# Processing Record 14 of Set 7 | port hueneme
# Processing Record 15 of Set 7 | jequitinhonha
# Processing Record 16 of Set 7 | reporoa
# Processing Record 17 of Set 7 | progreso
# Processing Record 18 of Set 7 | lorengau
# Processing Record 19 of Set 7 | miguel auza
# Processing Record 20 of Set 7 | taveta
# City not found. Skipping...
# Processing Record 21 of Set 7 | gao
# Processing Record 22 of Set 7 | port moresby
# Processing Record 23 of Set 7 | xunchang
# Processing Record 24 of Set 7 | dalian
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | gat
# Processing Record 27 of Set 7 | toora-khem
# Processing Record 28 of Set 7 | poum
# Processing Record 29 of Set 7 | yerbogachen
# Processing Record 30 of Set 7 | atikokan
# Processing Record 31 of Set 7 | stonewall
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | churapcha
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | kaitangata
# Processing Record 36 of Set 7 | tabou
# Processing Record 37 of Set 7 | fort-shevchenko
# Processing Record 38 of Set 7 | challapata
# City not found. Skipping...
# Processing Record 39 of Set 7 | taksimo
# Processing Record 40 of Set 7 | chase
# Processing Record 41 of Set 7 | severnyy
# City not found. Skipping...
# Processing Record 42 of Set 7 | gunjur
# Processing Record 43 of Set 7 | lewisporte
# Processing Record 44 of Set 7 | grand centre
# Processing Record 45 of Set 7 | dwarka
# Processing Record 46 of Set 7 | salvador
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | chara
# Processing Record 49 of Set 7 | khor
# Processing Record 50 of Set 7 | bacolod
# Processing Record 51 of Set 7 | mogadishu
# Processing Record 1 of Set 8 | znamenskoye
# Processing Record 2 of Set 8 | chokwe
# Processing Record 3 of Set 8 | powell river
# Processing Record 4 of Set 8 | vardo
# Processing Record 5 of Set 8 | vangaindrano
# City not found. Skipping...
# Processing Record 6 of Set 8 | egvekinot
# Processing Record 7 of Set 8 | dawei
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | fujinomiya
# Processing Record 10 of Set 8 | tarquinia
# City not found. Skipping...
# Processing Record 11 of Set 8 | tiznit
# Processing Record 12 of Set 8 | ati
# Processing Record 13 of Set 8 | cap malheureux
# Processing Record 14 of Set 8 | portland
# Processing Record 15 of Set 8 | aklavik
# Processing Record 16 of Set 8 | puerto narino
# Processing Record 17 of Set 8 | sosnovo-ozerskoye
# Processing Record 18 of Set 8 | morro bay
# Processing Record 19 of Set 8 | uruacu
# Processing Record 20 of Set 8 | copertino
# Processing Record 21 of Set 8 | george
# Processing Record 22 of Set 8 | gaffney
# Processing Record 23 of Set 8 | roald
# Processing Record 24 of Set 8 | ampanihy
# Processing Record 25 of Set 8 | vagay
# Processing Record 26 of Set 8 | tommot
# Processing Record 27 of Set 8 | iqaluit
# Processing Record 28 of Set 8 | yabelo
# Processing Record 29 of Set 8 | tucurui
# Processing Record 30 of Set 8 | port macquarie
# Processing Record 31 of Set 8 | carlos antonio lopez
# Processing Record 32 of Set 8 | grenville
# Processing Record 33 of Set 8 | dubuque
# Processing Record 34 of Set 8 | riesa
# Processing Record 35 of Set 8 | akdepe
# Processing Record 36 of Set 8 | chubbuck
# Processing Record 37 of Set 8 | constitucion
# Processing Record 38 of Set 8 | omsukchan
# Processing Record 39 of Set 8 | grand river south east
# Processing Record 40 of Set 8 | cairns
# Processing Record 41 of Set 8 | ilhabela
# Processing Record 42 of Set 8 | tual
# Processing Record 43 of Set 8 | kavaratti
# Processing Record 44 of Set 8 | ahuimanu
# Processing Record 45 of Set 8 | bestobe
# Processing Record 46 of Set 8 | leshukonskoye
# Processing Record 47 of Set 8 | malakal
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | sao joao da barra
# City not found. Skipping...
# Processing Record 50 of Set 8 | havoysund
# Processing Record 51 of Set 8 | ekhabi
# Processing Record 1 of Set 9 | talnakh
# Processing Record 2 of Set 9 | snasa
# Processing Record 3 of Set 9 | ierapetra
# Processing Record 4 of Set 9 | tonj
# Processing Record 5 of Set 9 | derzhavinsk
# Processing Record 6 of Set 9 | gourdon
# Processing Record 7 of Set 9 | roblin
# Processing Record 8 of Set 9 | katobu
# Processing Record 9 of Set 9 | gweru
# Processing Record 10 of Set 9 | kouango
# Processing Record 11 of Set 9 | san blas
# Processing Record 12 of Set 9 | whitefish
# Processing Record 13 of Set 9 | abha
# Processing Record 14 of Set 9 | pionerskiy
# Processing Record 15 of Set 9 | kota kinabalu
# Processing Record 16 of Set 9 | mattru
# Processing Record 17 of Set 9 | rio gallegos
# Processing Record 18 of Set 9 | casa nova
# Processing Record 19 of Set 9 | taunggyi
# Processing Record 20 of Set 9 | borger
# Processing Record 21 of Set 9 | nara
# Processing Record 22 of Set 9 | podosinovets
# Processing Record 23 of Set 9 | elena
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | madimba
# Processing Record 26 of Set 9 | bundaberg
# Processing Record 27 of Set 9 | vestmannaeyjar
# Processing Record 28 of Set 9 | sikasso
# Processing Record 29 of Set 9 | merida
# Processing Record 30 of Set 9 | mahanoro
# Processing Record 31 of Set 9 | cabo san lucas
# City not found. Skipping...
# Processing Record 32 of Set 9 | san roque
# Processing Record 33 of Set 9 | araouane
# City not found. Skipping...
# Processing Record 34 of Set 9 | olot
# Processing Record 35 of Set 9 | polohy
# Processing Record 36 of Set 9 | marsh harbour
# Processing Record 37 of Set 9 | port lincoln
# Processing Record 38 of Set 9 | mehamn
# Processing Record 39 of Set 9 | castelo do piaui
# Processing Record 40 of Set 9 | san andres
# Processing Record 41 of Set 9 | san jeronimo
# City not found. Skipping...
# Processing Record 42 of Set 9 | wilmington
# Processing Record 43 of Set 9 | honiara
# Processing Record 44 of Set 9 | marzuq
# Processing Record 45 of Set 9 | coquimbo
# Processing Record 46 of Set 9 | maubeuge
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | kihei
# Processing Record 50 of Set 9 | pedasi
# Processing Record 51 of Set 9 | boguchany
# Processing Record 1 of Set 10 | vilyuysk
# City not found. Skipping...
# Processing Record 2 of Set 10 | martapura
# City not found. Skipping...
# Processing Record 3 of Set 10 | peterhead
# City not found. Skipping...
# Processing Record 4 of Set 10 | fare
# Processing Record 5 of Set 10 | gigmoto
# Processing Record 6 of Set 10 | tabas
# Processing Record 7 of Set 10 | opuwo
# Processing Record 8 of Set 10 | touros
# Processing Record 9 of Set 10 | santarem
# Processing Record 10 of Set 10 | livingston
# City not found. Skipping...
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | milkovo
# Processing Record 14 of Set 10 | guaruja
# Processing Record 15 of Set 10 | tezu
# Processing Record 16 of Set 10 | port angeles
# Processing Record 17 of Set 10 | coihaique
# Processing Record 18 of Set 10 | sicamous
# Processing Record 19 of Set 10 | tokomaru
# Processing Record 20 of Set 10 | zeya
# Processing Record 21 of Set 10 | tungor
# Processing Record 22 of Set 10 | anchorage
# Processing Record 23 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 10 | maldonado
# Processing Record 25 of Set 10 | magadan
# Processing Record 26 of Set 10 | goiatuba
# Processing Record 27 of Set 10 | bonthe
# Processing Record 28 of Set 10 | sadiqabad
# Processing Record 29 of Set 10 | flagstaff
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | vila franca do campo
# Processing Record 32 of Set 10 | manta
# City not found. Skipping...
# Processing Record 33 of Set 10 | saryg-sep
# Processing Record 34 of Set 10 | boden
# Processing Record 35 of Set 10 | livingstonia
# City not found. Skipping...
# Processing Record 36 of Set 10 | morehead
# Processing Record 37 of Set 10 | enkhuizen
# Processing Record 38 of Set 10 | mae hong son
# Processing Record 39 of Set 10 | argentan
# Processing Record 40 of Set 10 | houston
# Processing Record 41 of Set 10 | muzhi
# Processing Record 42 of Set 10 | ulladulla
# Processing Record 43 of Set 10 | sindor
# Processing Record 44 of Set 10 | maralal
# Processing Record 45 of Set 10 | jalu
# Processing Record 46 of Set 10 | katsuura
# Processing Record 47 of Set 10 | abu samrah
# Processing Record 48 of Set 10 | olafsvik
# Processing Record 49 of Set 10 | sarangani
# Processing Record 50 of Set 10 | edmundston
# Processing Record 51 of Set 10 | basoko
# Processing Record 1 of Set 11 | acapulco
# Processing Record 2 of Set 11 | sovetskiy
# Processing Record 3 of Set 11 | connersville
# Processing Record 4 of Set 11 | pindobacu
# Processing Record 5 of Set 11 | george town
# Processing Record 6 of Set 11 | corinto
# City not found. Skipping...
# Processing Record 7 of Set 11 | atambua
# Processing Record 8 of Set 11 | kathu
# Processing Record 9 of Set 11 | aquin
# Processing Record 10 of Set 11 | payakumbuh
# Processing Record 11 of Set 11 | maningrida
# Processing Record 12 of Set 11 | tucupita
# Processing Record 13 of Set 11 | puerto colombia
# Processing Record 14 of Set 11 | nouadhibou
# Processing Record 15 of Set 11 | koronowo
# Processing Record 16 of Set 11 | sabha
# Processing Record 17 of Set 11 | thyboron
# Processing Record 18 of Set 11 | krupina
# Processing Record 19 of Set 11 | iquitos
# Processing Record 20 of Set 11 | alyangula
# Processing Record 21 of Set 11 | killin
# City not found. Skipping...
# Processing Record 22 of Set 11 | traverse city
# Processing Record 23 of Set 11 | ciro marina
# Processing Record 24 of Set 11 | najran
# Processing Record 25 of Set 11 | barra patuca
# Processing Record 26 of Set 11 | nichinan
# Processing Record 27 of Set 11 | rawlins
# Processing Record 28 of Set 11 | shangrao
# Processing Record 29 of Set 11 | kununurra
# Processing Record 30 of Set 11 | athabasca
# Processing Record 31 of Set 11 | dongsheng
# Processing Record 32 of Set 11 | qaqortoq
# Processing Record 33 of Set 11 | barsovo
# Processing Record 34 of Set 11 | yeppoon
# Processing Record 35 of Set 11 | ojinaga
# City not found. Skipping...
# Processing Record 36 of Set 11 | moron
# Processing Record 37 of Set 11 | virginia beach
# Processing Record 38 of Set 11 | dillingen
# City not found. Skipping...
# Processing Record 39 of Set 11 | burpengary
# Processing Record 40 of Set 11 | tombouctou
# Processing Record 41 of Set 11 | semey
# City not found. Skipping...
# Processing Record 42 of Set 11 | freeport
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a dictionary to display the the data frame in rows and columns; 

dict_weather = {
    "City":city_data,
    "Clouds":clouds,
    "Country":countries,
    "Date":dates,
    "Humidity":humidity,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
# establish dataframe
display_weather = pd.DataFrame(dict_weather)
display_weather.head()
# Out:
#            City  Clouds Country        Date  Humidity      Lat       Lng  \
# 0   thomasville      70      US  1650586696        71  35.8826  -80.0820
# 1         digby     100      CA  1650586836        69  44.6169  -65.7655
# 2   mys shmidta      29      RU  1650586836        97  62.0589   48.6201
# 3       cotonou      95      BJ  1650586728        78   6.3654    2.4183
# 4  punta arenas      64      PH  1650586837        74   8.9897  125.3400
#
#    Max Temp  Wind Speed
# 0     66.29        3.60
# 1     44.58       14.09
# 2     23.74        1.36
# 3     81.57        3.11
# 4     81.86        5.70

# %%
# # output data to csv
# weather_dataframe.to_csv(output_data_file)

# %%
weather_dataframe.count()
# Out:
# City          550
# Clouds        550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
weather_dataframe.describe()
# Out:
#            Clouds          Date    Humidity         Lat         Lng  \
# count  550.000000  5.500000e+02  550.000000  550.000000  550.000000
# mean    62.858182  1.650587e+09   72.154545   22.718993   23.321327
# std     36.235541  8.758971e+01   22.228400   31.604035   88.772071
# min      0.000000  1.650586e+09    9.000000  -54.800000 -175.200000
# 25%     29.000000  1.650587e+09   61.250000   -3.084250  -49.926850
# 50%     75.000000  1.650587e+09   78.000000   25.351550   27.782950
# 75%     98.000000  1.650587e+09   89.000000   49.054475  100.349575
# max    100.000000  1.650587e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  550.000000  550.000000
# mean    60.617164    7.659891
# std     21.044026    5.650798
# min    -11.870000    0.000000
# 25%     47.190000    3.330000
# 50%     64.790000    6.030000
# 75%     78.307500   10.510000
# max     97.570000   35.990000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
